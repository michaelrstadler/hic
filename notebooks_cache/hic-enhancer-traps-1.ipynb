# %%
# Import public packages.
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi 
from importlib import reload
import pickle
import pandas as pd

# Import my packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import sys
from importlib import reload
sys.path.append('/Users/michaelstadler/Bioinformatics/Projects/insulators/bin')
from hic_jupyter import viewer
import hic_jupyter as hc

# %%
traps = pd.read_csv('/Users/michaelstadler/Desktop/good_enhancer_data.csv')

# %%
cutoff = 1e4
traps.loc[(traps['Distance to Right'] > cutoff) & (traps['Distance to Left'] > cutoff)]
# Out:
#        ID Chromosome     Start       End  Distance to Left  Distance to Right  \
# 141   902      chr2R  13035358  13035826             38236              11430
# 142  1953      chr3L  20682691  20682691             29786              11865
# 143  2116      chr2R  13035125  13035230             38003              12026
# 144   255      chr2R  15600420  15600420             26429              13433
# 145  2262       chrX  22575292  22575292             28196              57418
# 146  2359       chrX  22575439  22575439             28343              57271
# 147   399      chr2L  20166042  20166042             31119              81996
# 148  1093       chrX  17346192  17346338             31612              32666
# 149  3070      chr2L  20205173  20205173             70250              42865
# 150   443      chr2L  20204993  20204993             70070              43045
# 151  2531      chr2L  20204992  20204992             70069              43046
# 152  3538      chr2L  20201168  20201168             66245              46870
#
#      Closest Promoter  Left:Right Distance Ratio  \
# 141             11430                   3.345232
# 142             11865                   2.510409
# 143             12026                   3.160070
# 144             13433                   1.967468
# 145             28196                   0.491066
# 146             28343                   0.494893
# 147             31119                   0.379519
# 148             31612                   0.967734
# 149             42865                   1.638866
# 150             43045                   1.627831
# 151             43046                   1.627770
# 152             46870                   1.413377
#
#                          Left Genes  \
# 141                 ['FBtr0087793']
# 142                 ['FBtr0342779']
# 143                 ['FBtr0087793']
# 144                 ['FBtr0087349']
# 145                 ['FBtr0077361']
# 146                 ['FBtr0077361']
# 147  ['FBtr0345683', 'FBtr0081378']
# 148  ['FBtr0074429', 'FBtr0334458']
# 149  ['FBtr0345683', 'FBtr0081378']
# 150  ['FBtr0345683', 'FBtr0081378']
# 151  ['FBtr0345683', 'FBtr0081378']
# 152  ['FBtr0345683', 'FBtr0081378']
#
#                                        Right Genes
# 141                 ['FBtr0345360', 'FBtr0087797']
# 142                                ['FBtr0344836']
# 143                 ['FBtr0345360', 'FBtr0087797']
# 144  ['FBtr0340006', 'FBtr0304712', 'FBtr0300853']
# 145                                ['FBtr0077362']
# 146                                ['FBtr0077362']
# 147                                ['FBtr0344577']
# 148                                ['FBtr0309522']
# 149                                ['FBtr0344577']
# 150                                ['FBtr0344577']
# 151                                ['FBtr0344577']
# 152                                ['FBtr0344577']

# %%
reload(hc)
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-53-54'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks_reduced'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves/hic-53-54'
hc.viewer(data_folder, track_folder, save_folder)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('X', '3L…
# <img src="data:image/png;base64,..." width="668">
