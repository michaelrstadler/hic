# %%
# Import my packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import sys
from importlib import reload
sys.path.append('/Users/michaelstadler/Bioinformatics/Projects/hic/bin')
from hic_jupyter import viewer
import hic_jupyter as hc

# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/virilis-56to59-64'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/viewer_tracks'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/virilis'

# %%
viewer(data_folder, track_folder, save_folder, genometracks=False)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('scaffol…
# <img src="data:image/png;base64,..." width="432">

# %%
#reload(hc)
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-42'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/hic-53-54'
hc.viewer(data_folder, track_folder, save_folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6523227d8977> in <module>
#       2 data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-42'
#       3 save_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/hic-53-54'
# ----> 4 hc.viewer(data_folder, track_folder, save_folder)
#
# NameError: name 'hc' is not defined

# %%
reload(hc)
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-66-68'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/hic-66-68'
hc.viewer(data_folder, track_folder, save_folder)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('X', '3L…
# <img src="data:image/png;base64,..." width="360">

# %%
reload(hc)
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-67-69'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/hic-52'
hc.viewer(data_folder, track_folder, save_folder)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('X', '3L…
# <img src="data:image/png;base64,..." width="619">
