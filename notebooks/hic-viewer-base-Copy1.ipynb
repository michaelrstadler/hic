# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-69-71'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks_reduced'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves/20211104-hic-71'
bin_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/bin'

# %%
# Import packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import numpy as np
import sys
sys.path.append(bin_folder)
from hic_jupyter import viewer, load_viewer_file

# %%
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=True)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('2L', '2…
# <img src="data:image/png;base64,..." width="763">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im2/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im2/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# ...
