# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-72'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks_reduced'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves'
bin_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/bin'

# %%
# Import packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import numpy as np
import sys
sys.path.append(bin_folder)
from hic_jupyter import viewer

# %%
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=True)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('2L', '2…
# <img src="data:image/png;base64,..." width="1012">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 51200 is out of bounds for axis 0 with size 48000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 57600 is out of bounds for axis 0 with size 51400
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget_selection.py in _propagate_index(self, change)
#     233             self.label = label
#     234         if self.value is not value:
# --> 235             self.value = value
#     236
#     237     @validate('value')
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in chr_dropdown_onchange(change)
#     259         state.chr = new_chr
#     260         pos_slider.max = state.chr_maxes[new_chr]
# --> 261         update_position()
#     262
#     263     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 57600 is out of bounds for axis 0 with size 57200
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 57600 is out of bounds for axis 0 with size 57200
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 70400 is out of bounds for axis 0 with size 65000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget_selection.py in _propagate_index(self, change)
#     233             self.label = label
#     234         if self.value is not value:
# --> 235             self.value = value
#     236
#     237     @validate('value')
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in chr_dropdown_onchange(change)
#     258         new_chr = change['new']
#     259         state.chr = new_chr
# --> 260         pos_slider.max = state.chr_maxes[new_chr]
#     261         update_position()
#     262
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
# --> 593             value = self._cross_validate(obj, value)
#     594         return value
#     595
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in _cross_validate(self, obj, value)
#     597         if self.name in obj._trait_validators:
#     598             proposal = Bunch({'trait': self, 'value': value, 'owner': obj})
# --> 599             value = obj._trait_validators[self.name](obj, proposal)
#     600         elif hasattr(obj, '_%s_validate' % self.name):
#     601             meth_name = '_%s_validate' % self.name
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in __call__(self, *args, **kwargs)
#     905         """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#     906         if hasattr(self, 'func'):
# --> 907             return self.func(*args, **kwargs)
#     908         else:
#     909             return self._init_call(*args, **kwargs)
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget_int.py in _validate_max(self, proposal)
#     118             raise TraitError('setting max < min')
#     119         if max < self.value:
# --> 120             self.value = max
#     121         return max
#     122
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
# -> 1134         self.notify_change(Bunch(
#    1135             name=name,
#    1136             old=old_value,
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 57600 is out of bounds for axis 0 with size 48000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/envs/im/lib/python3.8/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in pos_slider_onchange(change)
#     347         new_pos = int(pos / (state.binsize * 200)) * state.binsize * 200
#     348         state.posL = new_pos
# --> 349         update_position()
#     350
#     351     ############################################################################
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in update_position()
#     201                 ax[1].axvline(0, color="gray", alpha=0.5)
#     202                 if (state.chr in state.track_data):
# --> 203                     ax[1].plot(state.track_data[state.chr][np.arange(track_binR, track_binL, -1)], np.arange(track_binL, track_binR))
#     204                 else:
#     205                     ax[1].plot(np.zeros(track_binR - track_binL), np.arange(track_binL, track_binR))
#
# IndexError: index 51200 is out of bounds for axis 0 with size 48000

# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-50'
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)
