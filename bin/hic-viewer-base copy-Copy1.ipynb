# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-57-viewerfiles'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks_reduced'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves/hic-57'
bin_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/bin'

# %%
# Import packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import numpy as np
import sys
#sys.path.append(bin_folder)
from stadc import viewer

# %%
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=True, figsize=18)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('2L', '2…
# <img src="data:image/png;base64,..." width="1296">

# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-50'
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)

# %%
a = np.loadtxt('/Users/michaelstadler/Bioinformatics/Projects/insulators/outputs/hic-72/test.txtinsulationscore.txt')
a = pd.Series(a)

# %%
a = [0,0,0,0,0,0,0,0.5,1,1.5,2,2,2,2,2,2,2]
a = pd.Series(a)
#plt.plot(a)
a.rolling(7, center=True).mean().diff(6).shift(-3).plot()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
a[500:]
# Out:
# 500    -inf
# 501    -inf
# 502    -inf
# 503    -inf
# 504    -inf
#        ...
# 7330   -inf
# 7331   -inf
# 7332   -inf
# 7333   -inf
# 7334   -inf
# Length: 6835, dtype: float64
