# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-71'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves'
bin_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/bin'

# %%
# Import packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import numpy as np
import sys
sys.path.append(bin_folder)
from hic_jupyter import viewer

# %%
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('2L', '2…
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-19854ff779f0> in <module>
# ----> 1 viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in viewer(data_folder, track_folder, save_folder, oldformat, genometracks)
#     464
#     465     # Create file for storing clicked coordinates and initialize function.
# --> 466     coord_filename = make_coord_file(save_folder, data_folder)
#     467     cid = fig.canvas.mpl_connect('button_press_event', click_coord)
#     468
#
# ~/Bioinformatics/Projects/insulators/bin/hic_jupyter.py in make_coord_file(save_folder, data_folder)
#     425             test = os.path.join(save_folder, 'clickedcoords_' + str(date.today()) + '-' + str(n) + '.txt')
#     426             if not os.path.exists(test):
# --> 427                 f = open(test, 'w')
#     428                 f.write('#' + data_folder + '\n')
#     429                 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/saves/clickedcoords_2021-10-05-1.txt'

# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/viewerfiles/hic-50'
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)
