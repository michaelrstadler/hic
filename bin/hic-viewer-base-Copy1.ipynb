# %%
data_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-69-71'
track_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_tracks'
save_folder = '/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/saves'
bin_folder = '/Users/michaelstadler/Bioinformatics/Projects/hic/bin'

# %%
# Import packages.
# %matplotlib inline
import matplotlib as mpl
# %matplotlib notebook
# %matplotlib notebook

import numpy as np
import sys
sys.path.append(bin_folder)
from hic_jupyter import viewer, load_viewer_file

# %%
viewer(data_folder, track_folder, save_folder, oldformat=False, genometracks=False)
# Out:
# GridspecLayout(children=(Dropdown(description='Chrom', layout=Layout(grid_area='widget001'), options=('2L', '2…
# <img src="data:image/png;base64,..." width="432">

# %%
from skimage import exposure

# %%
a = load_viewer_file('/Users/michaelstadler/Bioinformatics/Projects/insulators/viewer_data/viewer_files/hic-72/2L_0_200000_500.txt.gz')
b = exposure.equalize_hist(a)

# %%
b
# Out:
# array([[0.63138125, 0.63138125, 0.63138125, ..., 0.63138125, 0.63138125,
#         0.63138125],
#        [0.63138125, 0.63138125, 0.63138125, ..., 0.63138125, 0.63138125,
#         0.63138125],
#        [0.63138125, 0.63138125, 0.63138125, ..., 0.63138125, 0.63138125,
#         0.63138125],
#        ...,
#        [0.63138125, 0.63138125, 0.63138125, ..., 1.        , 0.99856375,
#         0.98928572],
#        [0.63138125, 0.63138125, 0.63138125, ..., 0.99856375, 1.        ,
#         0.99673632],
#        [0.63138125, 0.63138125, 0.63138125, ..., 0.98928572, 0.99673632,
#         0.99438998]])

# %%
import matplotlib.pyplot as plt
plt.hist(a);
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# ?exposure.equalize_adapthist
